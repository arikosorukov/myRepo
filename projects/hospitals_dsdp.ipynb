# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

hospital_data = pd.read_csv('Data/imi_results.csv', encoding="ISO-8859-1")

# %%
hospital_data.head()
# Out:
#    YEAR COUNTY   HOSPITAL  OSHPDID       Procedure/Condition  \
# 0  2016   AAAA  STATEWIDE      NaN     AAA Repair Unruptured
# 1  2016   AAAA  STATEWIDE      NaN                       AMI
# 2  2016   AAAA  STATEWIDE      NaN              Acute Stroke
# 3  2016   AAAA  STATEWIDE      NaN  Acute Stroke Hemorrhagic
# 4  2016   AAAA  STATEWIDE      NaN     Acute Stroke Ischemic
#
#   Risk Adjuested Mortality Rate # of Deaths # of Cases Hospital Ratings  \
# 0                           1.3          30       2358              NaN
# 1                           6.1        3178      52167              NaN
# 2                           9.1        5482      60184              NaN
# 3                          21.1        2580      12210              NaN
# 4                             5        2258      45141              NaN
#
#   LONGITUDE LATITUDE
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN

# %%
hospital_data.columns
hospital_data.head(20)
# Out:
#     YEAR   COUNTY          HOSPITAL      OSHPDID        Procedure/Condition  \
# 0   2016     AAAA         STATEWIDE          NaN      AAA Repair Unruptured
# 1   2016     AAAA         STATEWIDE          NaN                        AMI
# 2   2016     AAAA         STATEWIDE          NaN               Acute Stroke
# 3   2016     AAAA         STATEWIDE          NaN   Acute Stroke Hemorrhagic
# 4   2016     AAAA         STATEWIDE          NaN      Acute Stroke Ischemic
# 5   2016     AAAA         STATEWIDE          NaN  Acute Stroke Subarachnoid
# 6   2016     AAAA         STATEWIDE          NaN     Carotid Endarterectomy
# 7   2016     AAAA         STATEWIDE          NaN      Espophageal Resection
# 8   2016     AAAA         STATEWIDE          NaN              GI Hemorrhage
# 9   2016     AAAA         STATEWIDE          NaN              Heart Failure
# 10  2016     AAAA         STATEWIDE          NaN               Hip Fracture
# ...

# %%
#hospital_data['COUNTY'].value_counts()
hospital_data = hospital_data.drop(hospital_data[2:15])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 #hospital_data['COUNTY'].value_counts()
# ----> 2 hospital_data = hospital_data.drop(hospital_data[2:15])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
#hospital_data['Procedure/Condition'].value_counts()

# %%
hospital_data.groupby('Procedure/Condition')['# of Cases'].count()
# Out:
# Procedure/Condition
# AAA Repair Endo Unruptured     646
# AAA Repair Open Unruptured     169
# AAA Repair Unruptured         1172
# AMI                           3300
# Acute Stroke                  3399
# Acute Stroke Hemorrhagic      2995
# Acute Stroke Ischemic         3388
# Acute Stroke Subarachnoid     2568
# Carotid Endarterectomy        2741
# Espophageal Resection         1926
# GI Hemorrhage                 3411
# Heart Failure                 3494
# Hip Fracture                  3344
# PCI                           2750
# Pancreatic Cancer             1926
# Pancreatic Other              1926
# Pancreatic Resection          2351
# Pneumonia                     3515
# Name: # of Cases, dtype: int64
